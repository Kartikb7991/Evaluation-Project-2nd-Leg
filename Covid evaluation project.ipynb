# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58 entries, 0 to 57
# Data columns (total 18 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Province_State        58 non-null     object
#  1   Country_Region        58 non-null     object
#  2   Last_Update           58 non-null     object
#  3   Lat                   56 non-null     float64
#  4   Long_                 56 non-null     float64
#  5   Confirmed             58 non-null     int64
#  6   Deaths                58 non-null     int64
#  7   Recovered             42 non-null     float64
#  8   Active                58 non-null     int64
#  9   FIPS                  58 non-null     int64
#  10  Incident_Rate         56 non-null     float64
#  11  People_Tested         56 non-null     float64
#  12  People_Hospitalized   33 non-null     float64
#  13  Mortality_Rate        57 non-null     float64
#  14  UID                   58 non-null     int64
#  15  ISO3                  58 non-null     object
#  16  Testing_Rate          56 non-null     float64
#  17  Hospitalization_Rate  33 non-null     float64
# dtypes: float64(9), int64(5), object(4)
# memory usage: 8.3+ KB

# %%
df.describe()
# Out:
#              Lat       Long_      Confirmed        Deaths     Recovered  \
# count  56.000000   56.000000      58.000000     58.000000     42.000000
# mean   36.840089  -85.206614   26756.086207   1611.017241   7007.428571
# std    10.887035   49.754449   52562.031122   4084.750891  11674.490020
# min   -14.271000 -170.132000       0.000000      0.000000     13.000000
# 25%    34.594600 -101.165775    2596.000000     74.000000    970.000000
# 50%    39.061850  -87.944200   10148.500000    385.000000   3008.000000
# 75%    42.361650  -76.970625   29395.500000   1394.250000   7326.750000
# max    61.370700  145.673900  354370.000000  28636.000000  61886.000000
#
#               Active          FIPS  Incident_Rate  People_Tested  \
# count      58.000000     58.000000      56.000000   5.600000e+01
# mean    20070.724138   3288.086207     396.230806   2.258534e+05
# std     41294.705318  17408.350591     402.682539   2.987834e+05
# min         0.000000      1.000000       0.000000   1.240000e+02
# 25%       812.500000     18.250000     148.521021   4.608100e+04
# 50%      5644.500000     32.500000     250.477287   1.386545e+05
# 75%     19291.250000     47.750000     477.888542   2.796948e+05
# max    263848.000000  99999.000000    1821.620216   1.505836e+06
#
#        People_Hospitalized  Mortality_Rate           UID  Testing_Rate  \
# count            33.000000       57.000000  5.800000e+01     56.000000
# mean           4897.454545        4.458248  7.676194e+07   3894.186870
# std           13185.628145        2.135002  2.378302e+07   1933.169297
# min              65.000000        0.000000  1.600000e+01     97.702058
# 25%             535.000000        3.072626  8.400001e+07   2712.800275
# 50%            1493.000000        4.403318  8.400003e+07   3469.782532
# 75%            4389.000000        5.466238  8.400004e+07   4763.649736
# max           76410.000000        9.545549  8.410000e+07  11377.424690
#
#        Hospitalization_Rate
# count             33.000000
# mean              14.342541
# std                5.047403
# min                6.778043
# 25%               10.000000
# 50%               13.598326
# 75%               17.658649
# max               28.054438

# %%
df.shape
# Out:
# (58, 18)

# %%
df.isnull().sum()
# Out:
# Province_State           0
# Country_Region           0
# Last_Update              0
# Lat                      2
# Long_                    2
# Confirmed                0
# Deaths                   0
# Recovered               16
# Active                   0
# FIPS                     0
# Incident_Rate            2
# People_Tested            2
# People_Hospitalized     25
# Mortality_Rate           1
# UID                      0
# ISO3                     0
# Testing_Rate             2
# Hospitalization_Rate    25
# dtype: int64

# %%
sns.heatmap(df.isnull())

# %%
df.columns
# Out:
# Index(['Province_State', 'Country_Region', 'Last_Update', 'Lat', 'Long_',
#        'Confirmed', 'Deaths', 'Recovered', 'Active', 'FIPS', 'Incident_Rate',
#        'People_Tested', 'People_Hospitalized', 'Mortality_Rate', 'UID', 'ISO3',
#        'Testing_Rate', 'Hospitalization_Rate'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Province_State           0
# Country_Region           0
# Last_Update              0
# Lat                      2
# Long_                    2
# Confirmed                0
# Deaths                   0
# Recovered               16
# Active                   0
# FIPS                     0
# Incident_Rate            2
# People_Tested            2
# People_Hospitalized     25
# Mortality_Rate           1
# UID                      0
# ISO3                     0
# Testing_Rate             2
# Hospitalization_Rate    25
# dtype: int64

# %%
df['Lat'].dropna(inplace=True)
df['Hospitalization_Rate'].fillna(df['Hospitalization_Rate'].mean(),inplace=True)

df['Recovered'].fillna(df['Recovered'].mean(),inplace=True)

# %%
df.isnull().sum()
# Out:
# Province_State           0
# Country_Region           0
# Last_Update              0
# Lat                      2
# Long_                    2
# Confirmed                0
# Deaths                   0
# Recovered                0
# Active                   0
# FIPS                     0
# Incident_Rate            2
# People_Tested            2
# People_Hospitalized     25
# Mortality_Rate           1
# UID                      0
# ISO3                     0
# Testing_Rate             2
# Hospitalization_Rate     0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# Province_State          0
# Country_Region          0
# Last_Update             0
# Lat                     0
# Long_                   0
# Confirmed               0
# Deaths                  0
# Recovered               0
# Active                  0
# FIPS                    0
# Incident_Rate           0
# People_Tested           0
# People_Hospitalized     0
# Mortality_Rate          0
# UID                     0
# ISO3                    0
# Testing_Rate            0
# Hospitalization_Rate    0
# dtype: int64

# %%
sns.heatmap(df.isnull())

# %%
df['Last_Update']=pd.to_datetime(df['Last_Update'])

# %%
df.head()
# Out:
#   Province_State Country_Region         Last_Update      Lat     Long_  \
# 0        Alabama             US 2020-05-21 02:32:00  32.3182  -86.9023
# 3        Arizona             US 2020-05-21 02:32:00  33.7298 -111.4312
# 4       Arkansas             US 2020-05-21 02:32:00  34.9697  -92.3731
# 6       Colorado             US 2020-05-21 02:32:00  39.0598 -105.3111
# 7    Connecticut             US 2020-05-21 02:32:00  41.5978  -72.7554
#
#    Confirmed  Deaths    Recovered  Active  FIPS  Incident_Rate  People_Tested  \
# 0      13052     522  7007.428571   12530     1     266.194321       164450.0
# 3      14906     747  3773.000000   10386     4     204.788838       165435.0
# 4       5003     107  3852.000000    1044     5     165.782801        96258.0
# 6      22797    1299  3478.000000   18020     8     395.868121       131837.0
# 7      39017    3529  6264.000000   29224     9    1094.357902       190718.0
#
#    People_Hospitalized  Mortality_Rate       UID ISO3  Testing_Rate  \
# 0               1493.0        3.999387  84000001  USA   3353.942386
# 3               1792.0        5.011405  84000004  USA   2272.859351
# 4                535.0        2.138717  84000005  USA   3189.670370
# 6               3955.0        5.698118  84000008  USA   2289.339188
# 7              10946.0        9.044775  84000009  USA   5349.302875
#
#    Hospitalization_Rate
# 0             11.438860
# 3             12.022005
# 4             10.693584
# 6             17.348774
# 7             28.054438

# %%
df['Last_Update']=df['Last_Update'].map(dt.datetime.toordinal)

# %%
sns.lineplot(x='Confirmed',y='Recovered',data=df)

# %%
plt.figure(figsize=(16,10))
sns.barplot(x='Confirmed',y='Recovered',data=df)

# %%
sns.pairplot(df)

# %%
df_active=df['Confirmed']-df['Deaths']

# %%
top=df[df['Last_Update']==df['Last_Update'].max()]
world=top.groupby('Province_State')['Confirmed','Recovered','Deaths'].sum().reset_index()
world.head()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   Province_State  Confirmed    Recovered  Deaths
# 0        Alabama      13052  7007.428571     522
# 1        Arizona      14906  3773.000000     747
# 2       Arkansas       5003  3852.000000     107
# 3       Colorado      22797  3478.000000    1299
# 4    Connecticut      39017  6264.000000    3529

# %%
top_confirmed=top.groupby(by='Province_State')['Confirmed'].sum().sort_values(ascending=False).head(20).reset_index()

# %%
top_confirmed
# Out:
#     Province_State  Confirmed
# 0         New York     354370
# 1    Massachusetts      88970
# 2          Florida      47471
# 3         Maryland      42323
# 4          Georgia      39801
# 5      Connecticut      39017
# 6         Virginia      32908
# 7             Ohio      29436
# 8          Indiana      29274
# 9         Colorado      22797
# 10       Tennessee      18412
# 11       Minnesota      17670
# 12         Arizona      14906
# 13       Wisconsin      13413
# 14    Rhode Island      13356
# 15         Alabama      13052
# 16     Mississippi      11967
# 17  South Carolina       9175
# 18          Kansas       8507
# 19        Kentucky       8167

# %%
plt.figure(figsize=(15,10))
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.xlabel('Confirmed',fontsize=30)
plt.ylabel('Province_State',fontsize=30)
plt.title('top 20 countries hving most confirmed cases',fontsize=30)
ax=sns.barplot(x=top_confirmed.Confirmed,y=top_confirmed.Province_State)

# %%
top_Deaths=top.groupby(by='Province_State')['Deaths'].sum().sort_values(ascending=False).head(20).reset_index()

# %%
plt.figure(figsize=(15,10))
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.xlabel('Deaths',fontsize=30)
plt.ylabel('Country',fontsize=30)
plt.title('top 20 countries hving most Deaths',fontsize=30)
ax=sns.barplot(x=top_Deaths.Deaths,y=top_Deaths.Province_State)

# %%
df.head()
# Out:
#   Province_State Country_Region  Last_Update      Lat     Long_  Confirmed  \
# 0        Alabama             US       737566  32.3182  -86.9023      13052
# 3        Arizona             US       737566  33.7298 -111.4312      14906
# 4       Arkansas             US       737566  34.9697  -92.3731       5003
# 6       Colorado             US       737566  39.0598 -105.3111      22797
# 7    Connecticut             US       737566  41.5978  -72.7554      39017
#
#    Deaths    Recovered  Active  FIPS  Incident_Rate  People_Tested  \
# 0     522  7007.428571   12530     1     266.194321       164450.0
# 3     747  3773.000000   10386     4     204.788838       165435.0
# 4     107  3852.000000    1044     5     165.782801        96258.0
# 6    1299  3478.000000   18020     8     395.868121       131837.0
# 7    3529  6264.000000   29224     9    1094.357902       190718.0
#
#    People_Hospitalized  Mortality_Rate       UID ISO3  Testing_Rate  \
# 0               1493.0        3.999387  84000001  USA   3353.942386
# 3               1792.0        5.011405  84000004  USA   2272.859351
# 4                535.0        2.138717  84000005  USA   3189.670370
# 6               3955.0        5.698118  84000008  USA   2289.339188
# 7              10946.0        9.044775  84000009  USA   5349.302875
#
#    Hospitalization_Rate
# 0             11.438860
# 3             12.022005
# 4             10.693584
# 6             17.348774
# 7             28.054438

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
catcols = ['Province_State',"Country_Region","ISO3",]
for x in catcols:
    df[x] = le.fit_transform(df[x])

# %%
df.head()
# Out:
#    Province_State  Country_Region  Last_Update      Lat     Long_  Confirmed  \
# 0               0               0       737566  32.3182  -86.9023      13052
# 3               1               0       737566  33.7298 -111.4312      14906
# 4               2               0       737566  34.9697  -92.3731       5003
# 6               3               0       737566  39.0598 -105.3111      22797
# 7               4               0       737566  41.5978  -72.7554      39017
#
#    Deaths    Recovered  Active  FIPS  Incident_Rate  People_Tested  \
# 0     522  7007.428571   12530     1     266.194321       164450.0
# 3     747  3773.000000   10386     4     204.788838       165435.0
# 4     107  3852.000000    1044     5     165.782801        96258.0
# 6    1299  3478.000000   18020     8     395.868121       131837.0
# 7    3529  6264.000000   29224     9    1094.357902       190718.0
#
#    People_Hospitalized  Mortality_Rate       UID  ISO3  Testing_Rate  \
# 0               1493.0        3.999387  84000001     0   3353.942386
# 3               1792.0        5.011405  84000004     0   2272.859351
# 4                535.0        2.138717  84000005     0   3189.670370
# 6               3955.0        5.698118  84000008     0   2289.339188
# 7              10946.0        9.044775  84000009     0   5349.302875
#
#    Hospitalization_Rate
# 0             11.438860
# 3             12.022005
# 4             10.693584
# 6             17.348774
# 7             28.054438

# %%
X = df.drop(columns=['Deaths'], axis=1)
y = df['Deaths']

# %%
X.shape
# Out:
# (33, 17)

# %%
y.shape
# Out:
# (33,)

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc=StandardScaler()

# %%
X=sc.fit_transform(df.drop(columns=['Deaths'], axis=1))

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.metrics import accuracy_score

# %%
reg = LinearRegression()
reg.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
Y_Pred = reg.predict(X_test)
Y_Pred
# Out:
# array([ 924.33677586, 1721.4085688 ,  -70.71194993,  209.76310973,
#         438.48777567, 2095.07524499,  539.28266136,  736.33404631,
#         -74.83742092,  267.00633689])

# %%
# finding the mean squared error and variance
mse = mean_squared_error(y_test, Y_Pred)
print('RMSE :', np.sqrt(mse))
print('Variance score: %.2f' % r2_score(y_test, Y_Pred))
# Out:
# RMSE : 463.28665888550694
# Variance score: 0.23
